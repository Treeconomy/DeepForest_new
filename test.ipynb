# %%
from models.new_resnet import create_model_with_weights

# %%
import torch
import pickle

# Load the model (assuming it's an OrderedDict)
model = torch.load("/home/nadja/DeepForest_new/deepforest/data/NEON.pt")

# Save the weights to a file
with open("/home/nadja/DeepForest_new/deepforest/data/NEON_weights.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
model_path = 'data/NEON_weights.pkl'
model= create_model_with_weights( model_path)
# Out:
# Used key: backbone.body.layer1.1.bn2.running_mean
# Used key: backbone.body.layer3.1.bn2.running_var
# Used key: backbone.body.layer3.2.bn3.running_mean
# Used key: backbone.body.layer1.0.bn3.bias
# Used key: backbone.body.layer3.3.bn2.bias
# Used key: backbone.body.layer4.0.bn1.bias
# Used key: backbone.fpn.inner_blocks.1.bias
# Used key: backbone.body.layer1.2.bn3.weight
# Used key: backbone.body.layer2.0.conv3.weight
# Used key: backbone.body.layer3.1.conv1.weight
# Used key: backbone.body.layer2.0.bn2.weight
# Used key: backbone.body.layer2.1.bn3.weight
# Used key: backbone.fpn.inner_blocks.2.bias
# Used key: backbone.body.layer1.1.bn1.running_mean
# Used key: backbone.body.layer1.0.bn1.running_mean
# Used key: head.classification_head.cls_logits.bias
# Used key: backbone.body.layer3.4.bn2.running_mean
# Used key: backbone.body.layer3.0.downsample.1.bias
# Used key: backbone.body.layer3.3.bn2.running_var
# Used key: backbone.body.layer3.4.bn3.running_var
# Used key: backbone.body.layer3.5.bn3.weight
# Used key: backbone.body.layer3.5.bn3.bias
# Used key: backbone.body.layer4.2.bn2.running_mean
# Used key: backbone.body.layer2.0.bn1.bias
# Used key: backbone.body.layer2.1.conv1.weight
# Used key: head.regression_head.bbox_reg.bias
# Used key: head.regression_head.conv.6.weight
# Used key: backbone.body.layer3.0.downsample.1.running_mean
# Used key: backbone.body.layer2.3.bn1.bias
# Used key: backbone.body.layer1.2.bn3.running_var
# Used key: backbone.body.layer2.3.bn1.running_var
# Used key: backbone.body.layer3.4.bn1.running_var
# Used key: backbone.body.layer3.0.bn1.weight
# Used key: backbone.body.layer3.3.conv1.weight
# Used key: backbone.body.layer2.0.bn2.bias
# Used key: backbone.body.layer2.3.conv2.weight
# Used key: backbone.body.layer3.2.conv2.weight
# Used key: backbone.body.layer4.0.bn3.running_mean
# Used key: backbone.body.bn1.weight
# Used key: backbone.body.layer1.1.conv1.weight
# Used key: backbone.body.layer3.5.bn1.weight
# Used key: backbone.body.layer4.1.bn3.bias
# Used key: backbone.body.layer3.1.bn3.running_mean
# Used key: head.classification_head.conv.0.bias
# Used key: backbone.body.layer2.1.bn1.bias
# Used key: backbone.body.layer4.1.bn3.running_mean
# Used key: backbone.body.layer2.0.downsample.1.weight
# Used key: backbone.body.layer2.1.conv2.weight
# Used key: backbone.body.layer3.0.bn3.running_var
# Used key: backbone.body.layer4.1.bn2.weight
# Used key: backbone.body.layer1.1.bn3.bias
# Used key: backbone.body.layer1.1.bn2.weight
# Used key: backbone.body.layer1.1.bn3.running_mean
# Used key: backbone.body.layer3.2.bn2.running_var
# Used key: backbone.body.layer3.5.bn1.bias
# Used key: head.regression_head.bbox_reg.weight
# Used key: backbone.body.layer1.0.bn2.weight
# Used key: backbone.body.layer4.0.conv2.weight
# Used key: backbone.body.layer2.2.bn1.running_mean
# Used key: backbone.body.bn1.running_var
# Used key: backbone.body.layer3.2.conv3.weight
# Used key: backbone.body.layer3.5.bn2.running_var
# Used key: backbone.fpn.layer_blocks.1.bias
# Used key: backbone.body.layer4.0.downsample.1.weight
# Used key: backbone.body.layer1.2.conv2.weight
# Used key: head.classification_head.conv.6.bias
# Used key: backbone.body.layer3.0.bn1.bias
# Used key: backbone.body.layer2.2.bn1.bias
# Used key: backbone.body.layer2.3.bn2.bias
# Used key: head.regression_head.conv.2.bias
# Used key: backbone.body.layer3.3.bn2.running_mean
# Used key: backbone.body.layer2.0.bn3.bias
# Used key: backbone.body.layer3.4.conv1.weight
# Used key: backbone.body.layer2.0.conv2.weight
# Used key: backbone.body.layer4.1.bn3.weight
# Used key: backbone.body.layer1.2.bn3.bias
# Used key: backbone.body.layer1.0.bn3.weight
# Used key: backbone.body.layer1.1.bn3.weight
# Used key: backbone.body.layer2.3.bn3.running_var
# Used key: backbone.body.layer1.1.bn1.running_var
# Used key: backbone.body.layer2.0.bn3.weight
# Used key: backbone.body.layer1.0.bn3.running_mean
# Used key: backbone.body.layer3.0.bn3.running_mean
# Used key: backbone.body.layer2.0.bn3.running_mean
# Used key: backbone.body.layer1.1.bn2.bias
# Used key: backbone.body.layer2.0.bn2.running_var
# Used key: backbone.body.layer2.1.bn2.bias
# Used key: backbone.body.layer3.2.bn1.running_var
# Used key: backbone.fpn.layer_blocks.2.weight
# Used key: backbone.body.layer4.0.bn3.weight
# Used key: backbone.body.layer1.0.bn3.running_var
# Used key: head.regression_head.conv.6.bias
# Used key: backbone.body.layer3.2.bn3.weight
# Used key: backbone.body.layer1.2.conv3.weight
# Used key: backbone.body.layer3.0.downsample.1.running_var
# Used key: backbone.body.layer4.0.bn1.running_mean
# Used key: backbone.fpn.extra_blocks.p6.weight
# Used key: backbone.body.layer3.4.bn2.bias
# Used key: backbone.body.layer4.1.bn1.running_mean
# Used key: backbone.body.layer4.1.bn2.running_mean
# Used key: backbone.body.layer3.1.bn3.bias
# Used key: backbone.body.layer3.4.bn1.weight
# Used key: backbone.body.layer1.0.bn2.running_mean
# Used key: backbone.fpn.inner_blocks.2.weight
# Used key: backbone.body.layer3.1.conv3.weight
# Used key: backbone.body.layer3.4.conv2.weight
# Used key: backbone.body.layer3.1.bn1.running_var
# Used key: head.regression_head.conv.0.bias
# Used key: backbone.body.layer2.3.bn3.bias
# Used key: backbone.body.layer3.5.conv1.weight
# Used key: backbone.body.layer3.1.bn3.weight
# Used key: backbone.body.layer2.3.conv1.weight
# Used key: backbone.body.layer3.2.bn2.weight
# Used key: backbone.body.layer3.3.bn1.running_mean
# Used key: backbone.body.layer4.0.bn1.weight
# Used key: backbone.body.layer1.0.bn1.running_var
# Used key: backbone.body.layer3.4.bn2.weight
# Used key: backbone.body.layer1.0.conv3.weight
# Used key: head.classification_head.conv.6.weight
# Used key: backbone.body.layer2.3.bn1.running_mean
# Used key: backbone.body.layer4.2.bn1.weight
# Used key: backbone.body.layer4.2.bn1.running_var
# Used key: backbone.body.layer1.0.downsample.1.bias
# Used key: backbone.body.layer3.0.conv3.weight
# Used key: backbone.body.layer3.3.bn3.bias
# Used key: backbone.body.layer4.2.conv3.weight
# Used key: backbone.body.layer4.2.bn3.bias
# Used key: backbone.body.layer3.4.bn2.running_var
# Used key: backbone.body.layer2.0.bn1.running_mean
# Used key: backbone.body.layer2.2.conv3.weight
# Used key: backbone.body.layer2.0.bn2.running_mean
# Used key: backbone.body.layer2.1.bn2.running_var
# Used key: backbone.body.layer2.1.bn2.running_mean
# Used key: backbone.body.layer3.4.bn3.weight
# Used key: backbone.body.layer4.0.bn1.running_var
# Used key: backbone.body.layer3.1.bn1.weight
# Used key: backbone.body.layer1.0.bn1.bias
# Used key: backbone.body.layer3.3.bn1.bias
# Used key: backbone.body.layer1.0.downsample.1.running_mean
# Used key: backbone.body.layer2.0.bn3.running_var
# Used key: backbone.body.layer2.2.conv1.weight
# Used key: backbone.body.layer4.2.bn3.running_var
# Used key: head.regression_head.conv.4.weight
# Used key: backbone.body.layer2.1.bn1.weight
# Used key: backbone.body.layer3.3.bn3.weight
# Used key: backbone.fpn.layer_blocks.0.weight
# Used key: backbone.fpn.inner_blocks.1.weight
# Used key: backbone.body.layer3.1.bn2.weight
# Used key: backbone.body.layer2.2.bn3.weight
# Used key: backbone.body.layer1.0.downsample.1.running_var
# Used key: backbone.body.layer3.0.conv1.weight
# Used key: backbone.body.layer3.5.conv2.weight
# Used key: backbone.body.layer2.1.bn3.bias
# Used key: backbone.fpn.layer_blocks.2.bias
# Used key: backbone.body.layer1.2.bn2.running_mean
# Used key: backbone.body.layer1.2.bn2.running_var
# Used key: backbone.body.layer1.1.bn2.running_var
# Used key: backbone.body.layer2.2.bn2.weight
# Used key: head.classification_head.conv.2.weight
# Used key: backbone.body.layer2.3.bn3.weight
# Used key: backbone.body.layer4.1.bn2.running_var
# Used key: backbone.body.layer4.0.bn2.running_var
# Used key: backbone.body.layer3.1.bn1.running_mean
# Used key: backbone.body.layer2.2.bn1.running_var
# Used key: backbone.body.layer1.2.bn3.running_mean
# Used key: backbone.body.layer3.5.conv3.weight
# Used key: backbone.body.layer1.2.bn1.running_mean
# Used key: backbone.body.layer2.3.bn2.running_mean
# Used key: backbone.body.layer1.2.bn1.running_var
# Used key: backbone.fpn.inner_blocks.0.weight
# Used key: backbone.body.layer4.2.conv2.weight
# Used key: backbone.body.layer1.0.bn1.weight
# Used key: backbone.body.layer2.0.downsample.1.running_var
# Used key: backbone.body.layer2.2.bn3.bias
# Used key: backbone.body.layer2.2.conv2.weight
# Used key: backbone.body.layer3.4.bn1.running_mean
# Used key: backbone.fpn.layer_blocks.0.bias
# Used key: backbone.body.layer2.1.bn3.running_mean
# Used key: backbone.body.layer3.1.conv2.weight
# Used key: backbone.body.layer4.0.bn2.running_mean
# Used key: backbone.body.layer1.0.conv2.weight
# Used key: backbone.body.layer1.1.conv2.weight
# Used key: backbone.body.layer3.3.bn2.weight
# Used key: backbone.body.layer1.0.conv1.weight
# Used key: backbone.body.layer3.0.bn2.running_var
# Used key: backbone.body.layer3.2.bn2.running_mean
# Used key: backbone.body.layer4.0.bn2.bias
# Used key: backbone.body.layer4.1.bn1.running_var
# Used key: backbone.body.layer3.2.bn3.bias
# Used key: backbone.body.layer2.3.bn1.weight
# Used key: backbone.body.layer3.0.bn2.weight
# Used key: backbone.body.layer4.0.bn3.bias
# Used key: backbone.body.layer3.4.bn1.bias
# Used key: backbone.body.layer4.2.bn2.running_var
# Used key: backbone.body.layer3.2.bn1.running_mean
# Used key: head.classification_head.conv.0.weight
# Used key: backbone.body.layer3.0.downsample.0.weight
# Used key: backbone.body.layer4.2.bn2.bias
# Used key: backbone.body.layer2.0.bn1.running_var
# Used key: backbone.body.layer4.0.downsample.1.bias
# Used key: backbone.body.layer3.0.bn3.bias
# Used key: backbone.body.layer3.2.conv1.weight
# Used key: backbone.body.layer1.1.bn1.bias
# Used key: backbone.body.layer3.4.bn3.running_mean
# Used key: backbone.body.layer4.0.bn3.running_var
# Used key: backbone.body.layer3.5.bn1.running_mean
# Used key: backbone.body.bn1.running_mean
# Used key: backbone.body.layer1.2.bn1.weight
# Used key: backbone.body.layer1.1.conv3.weight
# Used key: head.regression_head.conv.4.bias
# Used key: backbone.body.layer3.0.conv2.weight
# Used key: backbone.body.layer4.0.bn2.weight
# Used key: backbone.body.layer3.1.bn2.running_mean
# Used key: backbone.body.layer2.1.bn2.weight
# Used key: backbone.fpn.layer_blocks.1.weight
# Used key: backbone.body.layer2.2.bn2.bias
# Used key: backbone.body.layer1.2.bn2.weight
# Used key: backbone.body.layer4.2.bn1.bias
# Used key: backbone.body.layer3.3.conv2.weight
# Used key: backbone.body.layer1.1.bn3.running_var
# Used key: backbone.body.layer3.1.bn2.bias
# Used key: backbone.body.layer2.2.bn2.running_mean
# Used key: backbone.body.layer2.3.bn2.running_var
# Used key: backbone.body.layer2.0.downsample.0.weight
# Used key: head.classification_head.conv.4.bias
# Used key: backbone.body.layer4.0.downsample.1.running_var
# Used key: backbone.body.layer2.3.bn3.running_mean
# Used key: head.regression_head.conv.2.weight
# Used key: backbone.body.layer1.2.bn1.bias
# Used key: backbone.fpn.extra_blocks.p7.weight
# Used key: backbone.body.layer4.2.conv1.weight
# Used key: backbone.body.layer4.0.downsample.1.running_mean
# Used key: backbone.body.layer2.3.conv3.weight
# Used key: backbone.body.layer2.0.downsample.1.bias
# Used key: backbone.body.layer3.2.bn3.running_var
# Used key: backbone.body.layer2.0.bn1.weight
# Used key: backbone.body.layer3.5.bn2.weight
# Used key: backbone.body.layer3.1.bn3.running_var
# Used key: backbone.body.layer2.1.conv3.weight
# Used key: backbone.body.layer4.2.bn1.running_mean
# Used key: backbone.body.layer1.0.downsample.0.weight
# Used key: backbone.body.layer3.5.bn1.running_var
# Used key: backbone.body.layer4.1.bn1.bias
# Used key: backbone.body.layer3.3.bn1.weight
# Used key: backbone.body.layer3.2.bn1.weight
# Used key: head.classification_head.conv.4.weight
# Used key: backbone.body.layer3.0.bn1.running_var
# Used key: backbone.body.layer4.1.conv1.weight
# Used key: backbone.body.layer2.3.bn2.weight
# Used key: head.classification_head.conv.2.bias
# Used key: backbone.body.layer4.0.conv1.weight
# Used key: backbone.body.layer3.0.bn3.weight
# Used key: backbone.body.layer3.0.bn2.running_mean
# Used key: backbone.body.layer4.1.bn1.weight
# Used key: backbone.body.layer4.1.conv2.weight
# Used key: backbone.body.layer2.2.bn3.running_mean
# Used key: backbone.body.layer3.3.bn3.running_var
# Used key: backbone.body.bn1.bias
# Used key: backbone.body.layer3.1.bn1.bias
# Used key: head.regression_head.conv.0.weight
# Used key: backbone.body.layer2.1.bn1.running_var
# Used key: backbone.body.layer4.2.bn2.weight
# Used key: backbone.body.layer4.2.bn3.running_mean
# Used key: backbone.body.layer1.0.bn2.bias
# Used key: backbone.body.layer2.2.bn3.running_var
# Used key: backbone.body.layer1.0.downsample.1.weight
# Used key: backbone.body.layer2.1.bn1.running_mean
# Used key: backbone.body.layer3.4.bn3.bias
# Used key: backbone.body.layer3.2.bn2.bias
# Used key: backbone.body.layer3.3.bn3.running_mean
# Used key: backbone.body.layer3.5.bn2.bias
# Used key: backbone.body.layer1.0.bn2.running_var
# Used key: backbone.fpn.extra_blocks.p7.bias
# Used key: backbone.body.layer1.2.conv1.weight
# Used key: backbone.body.layer1.2.bn2.bias
# Used key: backbone.body.layer3.0.bn2.bias
# Used key: backbone.body.layer3.5.bn2.running_mean
# Used key: backbone.body.layer1.1.bn1.weight
# Used key: backbone.body.layer2.1.bn3.running_var
# Used key: backbone.body.layer4.0.conv3.weight
# Used key: backbone.body.layer2.0.downsample.1.running_mean
# Used key: backbone.body.layer4.1.bn2.bias
# Used key: backbone.body.layer2.2.bn2.running_var
# Used key: backbone.body.layer4.1.conv3.weight
# Used key: backbone.body.layer2.2.bn1.weight
# Used key: backbone.body.layer3.5.bn3.running_var
# Used key: backbone.body.layer2.0.conv1.weight
# Used key: backbone.body.layer3.3.bn1.running_var
# Used key: backbone.body.layer3.0.bn1.running_mean
# Used key: backbone.fpn.extra_blocks.p6.bias
# Used key: backbone.body.conv1.weight
# Used key: backbone.body.layer4.1.bn3.running_var
# Used key: backbone.body.layer4.2.bn3.weight
# Used key: backbone.body.layer3.5.bn3.running_mean
# Used key: backbone.body.layer3.4.conv3.weight
# Used key: backbone.body.layer4.0.downsample.0.weight
# Used key: backbone.fpn.inner_blocks.0.bias
# Used key: backbone.body.layer3.2.bn1.bias
# Used key: backbone.body.layer3.0.downsample.1.weight
# Used key: backbone.body.layer3.3.conv3.weight
# Used key: head.classification_head.cls_logits.weight

# %%
print(model)
# Out:
# RetinaNet(
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(4, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0-2): 3 x Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelP6P7(
#         (p6): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (p7): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#   )
#   (anchor_generator): AnchorGenerator()
#   (head): RetinaNetHead(
#     (classification_head): RetinaNetClassificationHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (regression_head): RetinaNetRegressionHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (bbox_reg): Conv2d(256, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
# )

# %%
from deepforest import main

# Load the model
model = main.deepforest()
model.use_release()

# Save the weights
model.save_weights('NEON_weights.h5')
# Out:
# Reading config file: /home/nadja/DeepForest_new/deepforest/data/deepforest_config.yml
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 from deepforest import main
#       3 # Load the model
# ----> 4 model = main.deepforest()
#       5 model.use_release()
#       7 # Save the weights
#
# File ~/DeepForest_new/deepforest/main.py:92, in deepforest.__init__(self, num_classes, label_dict, transforms, config_file, config_args, model, existing_train_dataloader, existing_val_dataloader)
#      89 self.existing_train_dataloader = existing_train_dataloader
#      90 self.existing_val_dataloader = existing_val_dataloader
# ---> 92 self.model=create_model_with_weights(model_path='/home/nadja/DeepForest_new/deepforest/data/NEON_weights.pkl')
#      95 # Metrics
#      96 self.iou_metric = IntersectionOverUnion(
#      97     class_metrics=True, iou_threshold=self.config["validation"]["iou_threshold"])
#
# File ~/DeepForest_new/deepforest/models/new_resnet.py:42, in create_model_with_weights(model_path, num_input_channels)
#      39 backbone = create_backbone(num_input_channels)
#      41 # Load the weights from NEON_weights.pkl
# ---> 42 with open(model_path, 'rb') as f:
#      43     state_dict = pickle.load(f)
#      45 # Manipulate the state dictionary to replace the backbone.body.conv1.weight with the randomly initialized one
#      46 # expanded_conv1_weight = torch.cat([backbone.backbone.body.conv1.weight, torch.zeros(64, num_input_channels-4 , 7, 7)], dim=1)
#      47 # state_dict['backbone.body.conv1.weight'] = expanded_conv1_weight
#      48 # #backbone = backbone.backbone
#      49 # Extract the weights for conv1 from the original state dictionary
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nadja/DeepForest_new/deepforest/data/NEON_weights.pkl'

# %%
# Create a dummy tensor with 4 bands (batch size = 1, height = 224, width = 224)
dummy_input = torch.randn(1, 4, 224, 224)


# Pass the dummy input through the model
output = model(dummy_input)

# Print the shape of the output
print("Input shape:", dummy_input.shape)
print("Output shape:", output.shape)
# Out:
# Input shape: torch.Size([1, 4, 224, 224])
# Output shape: torch.Size([1, 1])

# %%
from deepforest.dataset import TreeDataset

# %%
td=TreeDataset()
#Get a single batch
td1=td.next()
td2=td.__getitem__(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 td=TreeDataset()
#
# TypeError: TreeDataset.__init__() missing 2 required positional arguments: 'csv_file' and 'root_dir'

# %%
from deepforest.models.retinanet import Model
import yaml

# Load the configuration from the YAML file
with open('/home/nadja/DeepForest_new/deepforest_config.yml', 'r') as f:
    config = yaml.safe_load(f)

# Create an instance of the Model class with the loaded config
model_instance = Model(config)

# Call the create_model method on the instance
model1 = model_instance.create_model()

# %%
print(model1)
# Out:
# RetinaNet(
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0-2): 3 x Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelP6P7(
#         (p6): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (p7): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#   )
#   (anchor_generator): AnchorGenerator()
#   (head): RetinaNetHead(
#     (classification_head): RetinaNetClassificationHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (regression_head): RetinaNetRegressionHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (bbox_reg): Conv2d(256, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
# )
